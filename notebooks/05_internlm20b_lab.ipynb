# %% [markdown]
# # Codec lab: internlm2_5-20b-chat — BF16 vs our NF4 driver
#
# **Kernel → Restart Kernel, then Run All.** This kernel must not already
# hold a model. Each codec runs in a **child process** that exits before the
# next one starts, so nvidia-smi actually comes back. Never two models at once.
#
# Order:
#
# 1. Record idle `nvidia-smi`.
# 2. Load **uncompressed BF16** in a worker, three prompts, worker **exits**.
# 3. Wait until VRAM is back near idle.
# 4. Load **compressed NF4** in a new worker, same three prompts, worker exits.
# 5. Draw two VRAM graphs side by side (left uncompressed, right compressed),
#    **same Y scale 0–12288 MiB**.
#
# Negative control on 12 GB. BF16 ~37 GiB. NF4 weights ~11 GiB; try the standard NF4 .chr first. TokenLoop splits fused wqkv (gs = 2 + n_q/n_kv). HuggingFace remote code needs einops and sentencepiece==0.1.99.
#
# **Honesty:** VRAM is the product metric. Decode tok/s is a different stack
# (HF dense GEMM vs fused NF4). Display VRAM is inside `nvidia-smi`. A CUDA OOM
# is written into `summary.notes` and the plate still draws; it is not a crashed
# cell and it is not a fake number.

# %% [markdown]
# ## Paths
#
# Weights are not in git. `sys.path` must include the repo so `import gpu.lab`
# resolves. BF16 and NF4 never share the card.

# %%
# Paths on this machine. Weights are not in git.
import sys
from datetime import datetime
from pathlib import Path

REPO = Path(r"C:\dev\deep-fold")
sys.path.insert(0, str(REPO))

MODEL_DIR = Path(r"C:\dev\models\internlm2_5-20b-chat")
CHR = Path(r"C:\dev\models\internlm2_5-20b.nf4.chr")
RUNS = Path(r"C:\dev\models\runs")
TITLE = 'internlm2_5-20b-chat'
PLATE_TITLE = 'internlm2_5-20b-chat on one RTX 3080 12 GB — NF4 driver against dense BF16'
TRUST_REMOTE_CODE = True
NF4_DRIVER = 'internlm2'
out_dir = RUNS / datetime.now().strftime("lab-internlm20b-%Y%m%d-%H%M%S")

print("REPO     ", REPO)
print("MODEL_DIR", MODEL_DIR, "exists" if MODEL_DIR.is_dir() else "MISSING")
print("CHR      ", CHR)
print(
    "CHR size ",
    f"{CHR.stat().st_size / 1024**3:.2f} GiB" if CHR.is_file() else "MISSING",
)
print("out_dir  ", out_dir)
print("driver   ", NF4_DRIVER)

COMPRESS_CMD = r"C:\dev\deep-fold\chr.exe compress --in C:\dev\models\internlm2_5-20b-chat --out C:\dev\models\internlm2_5-20b.nf4.chr --codec nf4 --quiet"
print("compress (CPU, single-threaded, hours for 14B+):")
print(COMPRESS_CMD)
# Out:
# REPO      C:\dev\deep-fold
# MODEL_DIR C:\dev\models\internlm2_5-20b-chat exists
# CHR       C:\dev\models\internlm2_5-20b.nf4.chr
# CHR size  9.83 GiB
# out_dir   C:\dev\models\runs\lab-internlm20b-20260913-141222
# driver    internlm2
# compress (CPU, single-threaded, hours for 14B+):
# C:\dev\deep-fold\chr.exe compress --in C:\dev\models\internlm2_5-20b-chat --out C:\dev\models\internlm2_5-20b.nf4.chr --codec nf4 --quiet

# %% [markdown]
# ## Plotly + Jinja2
#
# Quotes around version pins are required: an unquoted `>=` is a shell
# redirect. Kaleido is optional (PNG for README); HTML does not need it.

# %%
# Quotes are required: unquoted plotly>=5 is a shell redirect, not a version pin.
# %pip install "plotly>=5" "jinja2>=3.1.0"

# %% [markdown]
# ## GPU snapshot
#
# RTX 3080, **12288 MiB**. Do **not** `import torch` in this kernel — that would
# open a CUDA context here and sit under both workers. Workers own CUDA.
# `nvidia-smi` `used` includes the desktop compositor. Do not subtract it.

# %%
import subprocess

def nvidia_smi_query(fields: str) -> list[str]:
    cmd = [
        "nvidia-smi",
        f"--query-gpu={fields}",
        "--format=csv,nounits,noheader",
    ]
    out = subprocess.check_output(cmd, text=True, encoding="utf-8", errors="replace")
    return [x.strip() for x in out.strip().split(",")]


name, total, used, driver, temp, clock, pwr = nvidia_smi_query(
    "name,memory.total,memory.used,driver_version,temperature.gpu,clocks.sm,power.draw"
)
print(f"GPU: {name}")
print(f"Driver: {driver}")
print(f"Memory: {used} / {total} MiB (display is already inside used)")
print("Card limit: 12288 MiB")
print(f"Free roughly: {int(float(total)) - int(float(used))} MiB")
print(f"Now: {temp} °C, SM {clock} MHz, {pwr} W")
if float(used) > 4000:
    raise SystemExit(
        f"nvidia-smi is {used} MiB. Kernel → Restart Kernel, then Run All. "
        "This process is still holding a previous model."
    )
print("Idle enough to start. Isolated workers: BF16 child, exit, then NF4 child.")
# Out:
# GPU: NVIDIA GeForce RTX 3080
# Driver: 581.57
# Memory: 1377 / 12288 MiB (display is already inside used)
# Card limit: 12288 MiB
# Free roughly: 10911 MiB
# Now: 54 °C, SM 225 MHz, 41.33 W
# Idle enough to start. Isolated workers: BF16 child, exit, then NF4 child.

# %% [markdown]
# ## Harness
#
# `run_bf16(..., isolated=True)` / `run_nf4(..., isolated=True)` each spawn a
# child Python. The child loads the model, chats, unloads, **exits**. This
# kernel never holds the weights. Read `nvidia-smi` between the two cells.
#
# The plate is `comparison_figure`: VRAM is two graphs side by side, same Y.

# %%
from gpu.lab import MESSAGES, comparison_figure, run_bf16, run_nf4, write_artifacts
from gpu.lab.bundle import LabBundle
from gpu.lab.sampler import smi_used_mib

print("MESSAGES (identical for both codecs, independent turns):")
for i, text in enumerate(MESSAGES, start=1):
    print(f"  {i}. {text}")


def print_turns(session) -> None:
    if not session.messages:
        print("no replies (OOM or skipped). notes:", session.summary.get("notes"))
        return
    for row in session.messages:
        print("=" * 60)
        print(f"codec={row['codec']}  message_id={row['message_id']}")
        print("prompt:", row["prompt"])
        print("--- reply ---")
        print(row["response"])
        print(
            f"prompt_tokens={row['prompt_tokens']}  new_tokens={row['new_tokens']}  "
            f"prefill_ms={row['prefill_ms']:.1f}  decode_tok_s={row['decode_tok_s']:.2f}  "
            f"quality_ok={row['quality_ok']}"
        )


def smi_now(label: str):
    used = smi_used_mib()
    print(f"nvidia-smi used {used:.0f} MiB  ({label})" if used is not None else f"nvidia-smi n/a ({label})")
    return used
# Out:
# MESSAGES (identical for both codecs, independent turns):
#   1. Reply with one short sentence. What is the capital of France?
#   2. And the capital of Germany?
#   3. What is 17 times 19? Reply with the number only.

# %% [markdown]
# ## Phase A — uncompressed BF16
#
# Child process: HuggingFace dense weights. When the worker **exits**, VRAM
# must come back. Do not start phase B until `nvidia-smi` is near idle.

# %%
out_dir.mkdir(parents=True, exist_ok=True)
print("artifacts →", out_dir)
idle = smi_now("idle, before BF16 worker")

bf16 = run_bf16(
    out_dir=out_dir,
    model_dir=MODEL_DIR,
    trust_remote_code=TRUST_REMOTE_CODE,
    isolated=True,
)
print_turns(bf16)
print(bf16.summary)
smi_after_bf16 = smi_now("after BF16 worker exited")
peak_bf16 = bf16.summary.get("vram_peak_smi_mib")
print(f"BF16 peak smi {peak_bf16} MiB")
print("n_messages", bf16.summary.get("n_messages"))
# Out:
# artifacts → C:\dev\models\runs\lab-internlm20b-20260913-141222
# nvidia-smi used 1385 MiB  (idle, before BF16 worker)
# [isolated bf16] c:\Users\Professional\anaconda3\envs\torch-gpu\python.exe -m gpu.lab.worker --codec bf16 --out C:\dev\models\runs\lab-internlm20b-20260913-141222\bf16 --model-dir C:\dev\models\internlm2_5-20b-chat --chr C:\dev\models\qwen25-3b.nf4.chr --max-new-tokens 64 --max-seq 512 --interval 0.12 --trust-remote-code
# [bf16]    0.04s  start  codec=bf16, interval=0.12s
# [bf16]    0.55s  load_start  from_pretrained internlm2_5-20b-chat, bf16
# [bf16]   54.21s  load_end  load_s=53.6
# [bf16]   54.21s  warmup_start  8 greedy tokens, not in any reported number
# [bf16]  130.47s  unload_start  TypeError
# [bf16]  135.55s  unload_end  smi_after_unload=744 MiB, torch_alloc=0 MiB
# [bf16]  135.61s  stop  peak_smi=11977 MiB
#
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/339 [00:00<02:41,  2.09it/s]
# Loading weights:   2%|▏         | 6/339 [00:00<00:31, 10.67it/s]
# Loading weights:   2%|▏         | 8/339 [00:01<00:41,  7.92it/s]
# Loading weights:   3%|▎         | 11/339 [00:01<00:30, 10.73it/s]
# Loading weights:   4%|▍         | 14/339 [00:01<00:29, 11.10it/s]
# Loading weights:   5%|▍         | 16/339 [00:01<00:27, 11.83it/s]
# Loading weights:   5%|▌         | 18/339 [00:01<00:26, 12.04it/s]
# Loading weights:   6%|▌         | 20/339 [00:01<00:28, 11.06it/s]
# Loading weights:   6%|▋         | 22/339 [00:02<00:27, 11.32it/s]
# Loading weights:   7%|▋         | 24/339 [00:02<00:26, 11.99it/s]
# Loading weights:   8%|▊         | 26/339 [00:02<00:30, 10.25it/s]
# Loading weights:   8%|▊         | 28/339 [00:03<00:44,  7.02it/s]
# Loading weights:   9%|▉         | 31/339 [00:03<00:32,  9.48it/s]
# Loading weights:  10%|█         | 34/339 [00:03<00:25, 12.00it/s]
# Loading weights:  11%|█         | 36/339 [00:03<00:43,  6.96it/s]
# Loading weights:  12%|█▏        | 40/339 [00:04<00:30,  9.92it/s]
# Loading weights:  12%|█▏        | 42/339 [00:04<00:33,  8.84it/s]
# Loading weights:  13%|█▎        | 44/339 [00:05<00:49,  6.02it/s]
# Loading weights:  14%|█▍        | 47/339 [00:05<00:36,  7.91it/s]
# Loading weights:  14%|█▍        | 49/339 [00:05<00:52,  5.47it/s]
# Loading weights:  15%|█▍        | 50/339 [00:06<00:51,  5.62it/s]
# Loading weights:  16%|█▌        | 53/339 [00:06<00:35,  8.07it/s]
# Loading weights:  17%|█▋        | 56/339 [00:06<00:41,  6.90it/s]
# Loading weights:  17%|█▋        | 58/339 [00:07<00:47,  5.94it/s]
# Loading weights:  18%|█▊        | 61/339 [00:07<00:33,  8.25it/s]
# Loading weights:  19%|█▊        | 63/339 [00:08<00:54,  5.06it/s]
# Loading weights:  80%|███████▉  | 271/339 [00:38<00:09,  7.35it/s]
# Loading weights:  81%|████████  | 274/339 [00:39<00:10,  6.03it/s]
# Loading weights:  82%|████████▏ | 279/339 [00:39<00:08,  7.07it/s]
# Loading weights:  83%|████████▎ | 280/339 [00:40<00:08,  7.07it/s]
# Loading weights:  84%|████████▍ | 285/339 [00:40<00:05, 10.52it/s]
# Loading weights:  85%|████████▍ | 287/339 [00:40<00:05, 10.24it/s]
# Loading weights:  85%|████████▌ | 289/339 [00:40<00:05,  8.42it/s]
# Loading weights:  86%|████████▌ | 292/339 [00:41<00:09,  4.89it/s]
# Loading weights:  88%|████████▊ | 299/339 [00:42<00:05,  7.40it/s]
# Loading weights:  89%|████████▉ | 301/339 [00:43<00:06,  6.02it/s]
# Loading weights:  90%|████████▉ | 305/339 [00:43<00:04,  8.33it/s]
# Loading weights:  91%|█████████ | 307/339 [00:43<00:04,  7.53it/s]
# Loading weights:  91%|█████████ | 309/339 [00:44<00:04,  6.27it/s]
# Loading weights:  92%|█████████▏| 313/339 [00:44<00:02,  9.15it/s]
# Loading weights:  93%|█████████▎| 315/339 [00:44<00:02,  8.25it/s]
# Loading weights:  94%|█████████▎| 317/339 [00:45<00:03,  6.37it/s]
# Loading weights:  94%|█████████▍| 319/339 [00:45<00:02,  7.61it/s]
# Loading weights:  95%|█████████▍| 321/339 [00:45<00:02,  7.90it/s]
# Loading weights:  95%|█████████▌| 323/339 [00:45<00:01,  8.35it/s]
# Loading weights:  96%|█████████▌| 325/339 [00:46<00:02,  6.93it/s]
# Loading weights:  97%|█████████▋| 328/339 [00:46<00:01,  7.10it/s]
# Loading weights:  97%|█████████▋| 330/339 [00:46<00:01,  7.58it/s]
# Loading weights:  98%|█████████▊| 331/339 [00:47<00:02,  3.65it/s]
# Loading weights:  98%|█████████▊| 332/339 [00:48<00:03,  2.25it/s]
# Loading weights:  98%|█████████▊| 333/339 [00:49<00:02,  2.64it/s]
# Loading weights: 100%|█████████▉| 338/339 [00:50<00:00,  3.33it/s]
# Loading weights: 100%|██████████| 339/339 [00:51<00:00,  2.59it/s]
# Loading weights: 100%|██████████| 339/339 [00:51<00:00,  6.63it/s]
# [transformers] `get_max_cache_shape` is deprecated, and will be removed in version 5.16. Please use `get_max_length` instead
# no replies (OOM or skipped). notes: internlm2_5-20b-chat ships transformers-4.41 remote code and its prepare_inputs_for_generation cannot run on transformers 5: TypeError: can only concatenate tuple (not "int") to tuple. No BF16 decode numbers from this env; load-time VRAM above is the measurement. Not patched on purpose -- forcing the stock method drops cache_position and the model decodes fluent repetition instead of an answer, which would be a fake baseline. Recorded miss, not a crashed cell.
# {'codec': 'bf16', 'load_s': 53.6088, 'vram_before_mib': 1524.0, 'vram_after_load_smi_mib': 11919.0, 'vram_after_load_torch_mib': 37882.2, 'vram_peak_smi_mib': 11977.0, 'weight_mib': 37882.1, 'kv_mib': None, 'mean_ttft_ms': None, 'mean_decode_tok_s': None, 'n_messages': 0, 'quality_all_ok': False, 'notes': 'internlm2_5-20b-chat ships transformers-4.41 remote code and its prepare_inputs_for_generation cannot run on transformers 5: TypeError: can only concatenate tuple (not "int") to tuple. No BF16 decode numbers from this env; load-time VRAM above is the measurement. Not patched on purpose -- forcing the stock method drops cache_position and the model decodes fluent repetition instead of an answer, which would be a fake baseline. Recorded miss, not a crashed cell.'}
# nvidia-smi used 885 MiB  (after BF16 worker exited)
# BF16 peak smi 11977.0 MiB
# n_messages 0

# %% [markdown]
# ## Phase B — compressed NF4
#
# Budget says even NF4 weights plus CUDA exceed 12288 MiB. The cell will try
# `run_nf4` only if `internlm2_5-20b.nf4.chr` exists, and a CUDA OOM is a
# recorded miss, not a crash.

# %%
import time

nf4 = None
skip_nf4 = False
skip_reason = ''

if skip_nf4:
    print("NF4 skipped:", skip_reason)
elif not CHR.is_file():
    print("NF4 file missing:", CHR)
    print("Compress on CPU, then re-run this cell. Command:")
    print(globals().get("COMPRESS_CMD", "(no compress command for this notebook)"))
else:
    # Wait until the BF16 worker's VRAM is actually gone.
    deadline = time.time() + 45
    used = smi_now("before NF4 worker")
    while (
        used is not None
        and peak_bf16 is not None
        and used > float(peak_bf16) - 1500
        and time.time() < deadline
    ):
        time.sleep(1.0)
        used = smi_now("waiting for BF16 VRAM to drop")
    if (
        used is not None
        and peak_bf16 is not None
        and used > float(peak_bf16) - 1500
    ):
        raise SystemExit(
            f"nvidia-smi still {used:.0f} MiB after BF16 (peak {float(peak_bf16):.0f}). "
            "Restart the kernel so this process is not holding the dense model."
        )
    nf4 = run_nf4(
        out_dir=out_dir,
        model_dir=MODEL_DIR,
        chr_path=CHR,
        trust_remote_code=TRUST_REMOTE_CODE,
        isolated=True,
    )
    print_turns(nf4)
    print(nf4.summary)
    smi_now("after NF4 worker exited")

bundle = LabBundle()
bundle = bundle.merge(bf16.as_bundle())
if nf4 is not None:
    bundle = bundle.merge(nf4.as_bundle())
bundle.write(out_dir)
print("wrote CSVs to", out_dir)
print("codecs in bundle:", bundle.codecs)
# Out:
# nvidia-smi used 885 MiB  (before NF4 worker)
# [isolated nf4] c:\Users\Professional\anaconda3\envs\torch-gpu\python.exe -m gpu.lab.worker --codec nf4 --out C:\dev\models\runs\lab-internlm20b-20260913-141222\nf4 --model-dir C:\dev\models\internlm2_5-20b-chat --chr C:\dev\models\internlm2_5-20b.nf4.chr --max-new-tokens 64 --max-seq 512 --interval 0.12 --trust-remote-code
# [nf4]    0.04s  start  codec=nf4, interval=0.12s
# [nf4]    0.57s  load_start  load_model internlm2_5-20b.nf4.chr
# [nf4]   20.37s  load_end  load_s=19.8, 241 nf4 linears (9774.1 MiB), 97 bf16 tensors (1.14 MiB), embed=nf4-rows (288.1 MiB), tied_lm_head=False, total=10063.3 MiB, 11.4s
# [nf4]   20.73s  warmup_start  TokenLoop(layers=48, hidden=6144, q/kv=48/8x128, max_seq=512, groups=193, prefill_chunk=16, norm=exact, overlap=True, graph=off)
# [nf4]   24.90s  graph_capture  graph=linears
# [nf4]   24.90s  warmup_end  warmup_ms=3488, graph=linears
# [nf4]   24.91s  msg_send[1]  Reply with one short sentence. What is the capital of France?
# [nf4]   25.53s  first_token[1]  prefill done
# [nf4]   26.86s  msg_done[1]  8 new tokens, ttft=619 ms, 5.7 tok/s, stop=eos, quality_ok=true
# [nf4]   26.86s  msg_send[2]  And the capital of Germany?
# [nf4]   27.17s  first_token[2]  prefill done
# [nf4]   38.14s  msg_done[2]  64 new tokens, ttft=306 ms, 5.7 tok/s, stop=max_new_tokens, quality_ok=true
# [nf4]   38.15s  msg_send[3]  What is 17 times 19? Reply with the number only.
# [nf4]   38.76s  first_token[3]  prefill done
# [nf4]   39.98s  msg_done[3]  8 new tokens, ttft=618 ms, 5.8 tok/s, stop=eos, quality_ok=true
# [nf4]   43.43s  unload_start  del loop/model/tokenizer, gc, empty_cache
# [nf4]   44.05s  unload_end  smi_after_unload=1371 MiB, torch_alloc=8 MiB
# [nf4]   44.08s  stop  peak_smi=11783 MiB
# ============================================================
# codec=nf4  message_id=1
# prompt: Reply with one short sentence. What is the capital of France?
# --- reply ---
# Paris is the capital of France.
# prompt_tokens=23  new_tokens=8  prefill_ms=619.0  decode_tok_s=5.72  quality_ok=True
# ============================================================
# codec=nf4  message_id=2
# prompt: And the capital of Germany?
# --- reply ---
# The capital of Germany is Berlin. It has been the capital since 1990, following the reunification of East and West Germany. Berlin is not only the political center but also a major cultural, economic, and historical hub in Europe. It is known for its rich history, vibrant arts scene, and numerous landmarks such
# prompt_tokens=16  new_tokens=64  prefill_ms=305.8  decode_tok_s=5.74  quality_ok=True
# ============================================================
# codec=nf4  message_id=3
# prompt: What is 17 times 19? Reply with the number only.
# --- reply ---
# 17 * 19 = 323
# prompt_tokens=24  new_tokens=8  prefill_ms=617.5  decode_tok_s=5.76  quality_ok=True
# {'codec': 'nf4', 'load_s': 19.7625, 'vram_before_mib': 1011.0, 'vram_after_load_smi_mib': 11608.0, 'vram_after_load_torch_mib': 10273.3, 'vram_peak_smi_mib': 11783.0, 'weight_mib': 10062.1, 'kv_mib': 96.0, 'mean_ttft_ms': 514.107, 'mean_decode_tok_s': 5.74199, 'n_messages': 3, 'quality_all_ok': True, 'notes': 'gpu.host.load_model + gpu.loop.TokenLoop, graph=linears, max_seq=512, prefill_chunk=16; independent turns: KV reset between messages, each prompt is a clean prefill; ttft = prefill of the whole prompt; no from_pretrained, no transformers.generate'}
# nvidia-smi used 1050 MiB  (after NF4 worker exited)
# wrote CSVs to C:\dev\models\runs\lab-internlm20b-20260913-141222
# codecs in bundle: ['bf16', 'nf4']

# %% [markdown]
# ## One figure
#
# VRAM is **two graphs side by side**: left uncompressed BF16, right compressed
# NF4, **the same 0–12288 MiB Y scale**. If CUDA's working set is larger than
# the card (14B BF16 does this: nvidia-smi sits at 12 GB, torch holds ~28 GB
# in VRAM + shared GPU memory), a **second pair** is drawn directly underneath —
# same Y on both columns, high enough to show the spill into system RAM.
# Then budget, replies, TTFT, decode.

# %%
# One interactive figure. Not five charts. Not SVG.
fig = comparison_figure(bundle, title=PLATE_TITLE)
write_artifacts(fig, out_dir)
fig.show()
print("lab.html", out_dir / "lab.html")
# Out:
# lab.html C:\dev\models\runs\lab-internlm20b-20260913-141222\lab.html

# %% [markdown]
# ## Tables
#
# `messages.csv` is the chat log. `summary.csv` is one row per codec. Display
# the frames; do not screenshot them. Numbers come from the harness — this
# cell does not invent VRAM or tok/s.

# %%
import pandas as pd
from IPython.display import display

pd.set_option("display.max_colwidth", 80)
pd.set_option("display.width", 160)

messages = pd.read_csv(out_dir / "messages.csv")
summary = pd.read_csv(out_dir / "summary.csv")

print("messages.csv")
display(messages)
print("summary.csv")
display(summary)
print("artifacts in", out_dir)
for name in (
    "timeline.csv",
    "events.csv",
    "messages.csv",
    "summary.csv",
    "lab.html",
    "lab.png",
):
    p = out_dir / name
    print(f"  {name}: {'ok' if p.is_file() else 'missing (allowed for lab.png if kaleido skipped)'}")
# Out:
# messages.csv
#   codec  message_id                                                         prompt  \
# 0   nf4           1  Reply with one short sentence. What is the capital of France?
# 1   nf4           2                                    And the capital of Germany?
# 2   nf4           3               What is 17 times 19? Reply with the number only.
#
#                                                                           response  prompt_tokens  new_tokens  prefill_ms  decode_ms  decode_tok_s  \
# 0                                                  Paris is the capital of France.             23           8     618.984    1223.08       5.72325
# 1  The capital of Germany is Berlin. It has been the capital since 1990, follow...             16          64     305.808   10978.90       5.73825
# 2                                                                    17 * 19 = 323             24           8     617.530    1214.34       5.76445
#
#       stop_reason  quality_ok
# 0             eos        True
# 1  max_new_tokens        True
# 2             eos        True
# summary.csv
#   codec   load_s  vram_before_mib  vram_after_load_smi_mib  vram_after_load_torch_mib  vram_peak_smi_mib  weight_mib  kv_mib  mean_ttft_ms  mean_decode_tok_s  \
# 0  bf16  53.6088             1524                    11919                    37882.2              11977     37882.1     NaN           NaN                NaN
# 1   nf4  19.7625             1011                    11608                    10273.3              11783     10062.1    96.0       514.107            5.74199
#
#    n_messages  quality_all_ok                                                                            notes
# 0           0           False  internlm2_5-20b-chat ships transformers-4.41 remote code and its prepare_inp...
# 1           3            True  gpu.host.load_model + gpu.loop.TokenLoop, graph=linears, max_seq=512, prefil...
# artifacts in C:\dev\models\runs\lab-internlm20b-20260913-141222
#   timeline.csv: ok
#   events.csv: ok
#   messages.csv: ok
#   summary.csv: ok
#   lab.html: ok
#   lab.png: ok

# %% [markdown]
# ## How to read this
#
# VRAM is the claim. Tok/s is a different stack.
#
# - **VRAM.** After load, NF4 must sit well below BF16 on the same card. If the
#   two traces meet, the NF4 path materialized a layer into HBM — a bug, not a
#   compression win. There is **no `[M,K]` BF16** weight matrix on the NF4
#   path (`load_model` + `TokenLoop`, never `from_pretrained` on the shards).
#   `nvidia-smi` is **dedicated VRAM only** and stops at 12288 MiB. If CUDA
#   allocates more than that (14B BF16: torch ~28 GiB), the extra is Windows
#   **shared GPU memory** (system RAM). The plate then adds a second pair of
#   graphs under VRAM, same Y, so that spill is visible. Do not read a full
#   12 GB nvidia-smi line as “the model fit.”
# - **Tok/s.** BF16 is HuggingFace `generate` + dense GEMM. NF4 is our fused
#   dequant-MMA loop. Report both numbers. Do not say “we are faster” unless
#   the table says so.
# - **TTFT.** Prefill. BF16 uses the HF prefill; NF4 uses `N≤16` chunks.
# - **Display VRAM** is inside `nvidia-smi`. It is real. Do not subtract it.
# - **Independent turns.** Each prompt is a clean prefill. KV is not carried
#   across the three user messages, so TTFT stays comparable.
# - **OOM.** An empty `messages.csv` row-set plus `CUDA OOM` in `summary.notes`
#   is the 12 GB result for this variant. Do not invent a VRAM number for it.
#
# This notebook is **internlm2_5-20b-chat** only. `internlm2_5-20b.nf4.chr` is the compressed file for
# this model. Missing run → empty CSVs or a recorded skip, not fiction.
